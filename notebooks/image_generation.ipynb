# %%
print("Hello testing")
# Out:
# Hello testing

# %%
import os
from sys import path

from IPython.display import Image

path.append(os.path.realpath("../"))

# %%
from app.image_gen import img_fal_service

# %%
image = img_fal_service.generate_image_and_get_bytes("one girl with a teddy bear")
image
# Out:
# Generating image
# resolution {'width': 720, 'height': 1280} model fal-ai/playground-v25
# {'images': [{'url': 'https://fal.media/files/koala/sfDwF0ZeuMLoGAy-6v_Wn.jpeg', 'width': 704, 'height': 1280, 'content_type': 'image/jpeg'}], 'timings': {'inference': 2.263676520437002}, 'seed': 16272992818604241920, 'has_nsfw_concepts': [False], 'prompt': 'one girl with a teddy bear'}
# ...

# %%
Image(image)
